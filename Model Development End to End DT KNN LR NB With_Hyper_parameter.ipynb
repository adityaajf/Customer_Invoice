# %% [markdown]
# **Hyper parameter tuning**
#
# - The parameters or arguments of model can change by user to get the good model performance
#
# - Grid search
#
# - Random search
#
# - Assume that in Decsision tree we have following hyper parameter
#
#     - criterion : {"gini", "entropy", "log_loss"}
#
#     - splitter : {"best", "random"}
#
#     - max depth : {1,2,3,4,5,6}
#
# - By default we have criterion 'gini' is there
#
# - But the model might be performed when criterion is 'entropy' also
#
# - we need to test the combinations by providing different values
#
# - To try the combinations we have two methods
#
#     - Grid search:
#
#         - it is a step by step by consider the all combinations
#
#         - in criterion: 3,splitter: 2, max depth=6
#
#         - The total combinations are : 3x2x6=36
#
#     - Random search:
#
#         - It will not do all 36 possibile combiantions
#
#         - It will select randomly some combinations
#
# - Generally we do Grid search
#
# - By doing this we have term called Cross validation
#
#
# **Cross validation**:
#
# - Cross validation: CV
#
# - CV=4 means we devide data randomly into 4 parts
#
# - Out of these 4 parts every time 3 parts consider as train data, 1 parts consider as test data
#
# - P1  P2  P3  P4  are 4 parts of data
#
# - Combination1:  P1 + P2 + P3 are train data  and P4 as test data
#
#     - For Combination-1 will try to imporove model performance by doing Hyper parameter tuning
#
#     - Assume there 36 comninations are available in DT
#
#     - For the Combination1 will do all 36
#
#     - so we have 36 hyper parameter comninations for each combination will have one accuracy
#
#     - so we have total 36 accuracy values
#
# - Combination2:  P1 + P2 + P4   are train data  and   P3 as test data
#
#     - For Combination-2 will try to imporove model performance by doing Hyper parameter tuning
#
#     - Assume there 36 comninations are available in DT
#
#     - For the Combination-2 will do all 36
#
# - Combination3:  P1 + P3 + P4  are train data and P2 as test data
#
#     - For Combination-3 will try to imporove model performance by doing Hyper parameter tuning
#
#     - Assume there 36 comninations are available in DT
#
#     - For the Combination-3 will do all 36
#
# - Combination-4: P2 + P3 + P4  are train data and P1 as test data
#
#     - For Combination-4 will try to imporove model performance by doing Hyper parameter tuning
#
#     - Assume there 36 comninations are available in DT
#
#     - For the Combination-4 will do all 36
#
# - Every combination gives 36 accurcy values corresponding each hyper parameter
#
# - will calculate all the average accuracy of combinations individual accuracy w.r.t to each hyper parameter
#
# - so that will get 36 average accuracy values w.r.t each hyper parameter
#
# - Out of these 36 the maximum one is our best accuracy and corresponding hyper parameters are best parameters

# %%
import pandas as pd
indexes=[f"h_{i}" for i in range(1,37)]
col1=[f"combination_1_acc_{i}" for i in range(1,37)]
col2=[f"combination_2_acc_{i}" for i in range(1,37)]
col3=[f"combination_3_acc_{i}" for i in range(1,37)]
col4=[f"combination_4_acc_{i}" for i in range(1,37)]
col5=[f"avg_acc_{i}" for i in range(1,37)]
cols=['C1','C2','C3','C4','Avg acc']
pd.DataFrame(zip(col1,col2,col3,col4,col5),index=indexes,
            columns=cols)
# Out:
#                         C1                    C2                    C3  \
# h_1    combination_1_acc_1   combination_2_acc_1   combination_3_acc_1
# h_2    combination_1_acc_2   combination_2_acc_2   combination_3_acc_2
# h_3    combination_1_acc_3   combination_2_acc_3   combination_3_acc_3
# h_4    combination_1_acc_4   combination_2_acc_4   combination_3_acc_4
# h_5    combination_1_acc_5   combination_2_acc_5   combination_3_acc_5
# h_6    combination_1_acc_6   combination_2_acc_6   combination_3_acc_6
# h_7    combination_1_acc_7   combination_2_acc_7   combination_3_acc_7
# h_8    combination_1_acc_8   combination_2_acc_8   combination_3_acc_8
# h_9    combination_1_acc_9   combination_2_acc_9   combination_3_acc_9
# h_10  combination_1_acc_10  combination_2_acc_10  combination_3_acc_10
# h_11  combination_1_acc_11  combination_2_acc_11  combination_3_acc_11
# h_12  combination_1_acc_12  combination_2_acc_12  combination_3_acc_12
# h_13  combination_1_acc_13  combination_2_acc_13  combination_3_acc_13
# h_14  combination_1_acc_14  combination_2_acc_14  combination_3_acc_14
# h_15  combination_1_acc_15  combination_2_acc_15  combination_3_acc_15
# h_16  combination_1_acc_16  combination_2_acc_16  combination_3_acc_16
# h_17  combination_1_acc_17  combination_2_acc_17  combination_3_acc_17
# h_18  combination_1_acc_18  combination_2_acc_18  combination_3_acc_18
# h_19  combination_1_acc_19  combination_2_acc_19  combination_3_acc_19
# h_20  combination_1_acc_20  combination_2_acc_20  combination_3_acc_20
# h_21  combination_1_acc_21  combination_2_acc_21  combination_3_acc_21
# h_22  combination_1_acc_22  combination_2_acc_22  combination_3_acc_22
# h_23  combination_1_acc_23  combination_2_acc_23  combination_3_acc_23
# h_24  combination_1_acc_24  combination_2_acc_24  combination_3_acc_24
# h_25  combination_1_acc_25  combination_2_acc_25  combination_3_acc_25
# h_26  combination_1_acc_26  combination_2_acc_26  combination_3_acc_26
# h_27  combination_1_acc_27  combination_2_acc_27  combination_3_acc_27
# h_28  combination_1_acc_28  combination_2_acc_28  combination_3_acc_28
# h_29  combination_1_acc_29  combination_2_acc_29  combination_3_acc_29
# h_30  combination_1_acc_30  combination_2_acc_30  combination_3_acc_30
# h_31  combination_1_acc_31  combination_2_acc_31  combination_3_acc_31
# h_32  combination_1_acc_32  combination_2_acc_32  combination_3_acc_32
# h_33  combination_1_acc_33  combination_2_acc_33  combination_3_acc_33
# h_34  combination_1_acc_34  combination_2_acc_34  combination_3_acc_34
# h_35  combination_1_acc_35  combination_2_acc_35  combination_3_acc_35
# h_36  combination_1_acc_36  combination_2_acc_36  combination_3_acc_36
#
#                         C4     Avg acc
# h_1    combination_4_acc_1   avg_acc_1
# h_2    combination_4_acc_2   avg_acc_2
# h_3    combination_4_acc_3   avg_acc_3
# h_4    combination_4_acc_4   avg_acc_4
# h_5    combination_4_acc_5   avg_acc_5
# h_6    combination_4_acc_6   avg_acc_6
# h_7    combination_4_acc_7   avg_acc_7
# h_8    combination_4_acc_8   avg_acc_8
# h_9    combination_4_acc_9   avg_acc_9
# h_10  combination_4_acc_10  avg_acc_10
# h_11  combination_4_acc_11  avg_acc_11
# h_12  combination_4_acc_12  avg_acc_12
# h_13  combination_4_acc_13  avg_acc_13
# h_14  combination_4_acc_14  avg_acc_14
# h_15  combination_4_acc_15  avg_acc_15
# h_16  combination_4_acc_16  avg_acc_16
# h_17  combination_4_acc_17  avg_acc_17
# h_18  combination_4_acc_18  avg_acc_18
# h_19  combination_4_acc_19  avg_acc_19
# h_20  combination_4_acc_20  avg_acc_20
# h_21  combination_4_acc_21  avg_acc_21
# h_22  combination_4_acc_22  avg_acc_22
# h_23  combination_4_acc_23  avg_acc_23
# h_24  combination_4_acc_24  avg_acc_24
# h_25  combination_4_acc_25  avg_acc_25
# h_26  combination_4_acc_26  avg_acc_26
# h_27  combination_4_acc_27  avg_acc_27
# h_28  combination_4_acc_28  avg_acc_28
# h_29  combination_4_acc_29  avg_acc_29
# h_30  combination_4_acc_30  avg_acc_30
# h_31  combination_4_acc_31  avg_acc_31
# h_32  combination_4_acc_32  avg_acc_32
# h_33  combination_4_acc_33  avg_acc_33
# h_34  combination_4_acc_34  avg_acc_34
# h_35  combination_4_acc_35  avg_acc_35
# h_36  combination_4_acc_36  avg_acc_36

# %%
a model has
5 paramters
each paramter can opt a values
h1: 4, h2: 4 ,h3:3,h4:4, h5:6,
cv=4

# %%
GATE === M.tech seats all over India
GATE === Govt jobs PSU <1000 ==== IIT
Python ML SQL 
2014 B.tech
2018 GATE IIT Madras M.tech ==== Qualcome 30lakhs 
IT : GATE qualify
do : M.tech 

stop the study
MD 
MBBS 1lakhs 
BDS 

M.tech 
M.tech  I will not do job: Wrong
There is no placements in M.tech 2years 
B.tech 


IT === M.tech  Fisrt
M.tech === IIT  second

# %% [markdown]
# $Step-1$
#
# **Import the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(color_codes=True)             # To get diffent different colors
pd.set_option('display.max_columns', None)  # To display the max columns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,\
                            precision_score,\
                            recall_score,\
                            f1_score,\
                            classification_report,\
                            roc_auc_score,roc_curve,auc
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %% [markdown]
# $Step-2$:
#
# **Read the data**

# %%
data=pd.read_csv("preprocessd_data.csv")
data
# Out:
#       gender       age  no_of_days_subscribed  multi_screen  mail_subscribed  \
# 0          0 -0.264643              -0.946659             0                0
# 1          0  0.029654               1.235009             0                0
# 2          0  2.580235               0.658246             0                0
# 3          0 -1.441834               0.783629             0                1
# 4          0  0.127754               2.288228             0                0
# ...      ...       ...                    ...           ...              ...
# 3401       1 -0.805656               0.479710             0                0
# 3402       0  0.477826               0.674425             0                0
# 3403       0 -0.550521               0.426099             0                1
# 3404       0  0.004651              -0.444637             0                0
# 3405       0 -0.057028               0.317748             0                0
#
#       weekly_mins_watched  minimum_daily_mins  weekly_max_night_mins  \
# 0               -1.508785            0.722258              -0.944404
# 1                0.304821           -0.901748              -0.688523
# 2               -2.266627            0.613991              -0.483818
# 3                0.638123           -0.252146               0.079121
# 4               -0.333851            0.253101              -0.893228
# ...                   ...                 ...                    ...
# 3401             0.887802            0.552184               0.865765
# 3402             2.038061           -0.931071               0.567257
# 3403            -0.410669            0.344847              -0.729485
# 3404             1.359751           -0.847121              -0.715010
# 3405             2.844852            0.098115              -0.550251
#
#       videos_watched  customer_support_calls  churn
# 0          -1.403000               -0.415473      0
# 1          -0.599124                0.347522      0
# 2          -1.403000                2.636507      1
# 3          -0.197185                1.110517      0
# 4           1.008630               -0.415473      0
# ...              ...                     ...    ...
# 3401       -0.495634               -0.415473      1
# 3402        2.100185                0.235227      1
# 3403       -0.403904                1.873512      1
# 3404       -0.197185               -1.178468      1
# 3405        0.606692               -1.178468      1
#
# [3406 rows x 11 columns]

# %% [markdown]
# $Step-3$
#
# **Divide data into input and output**

# %%
# Here the target column is Customer Status
X = data.drop('churn', axis=1)
y = data['churn']

# %% [markdown]
# $Step-4$:
#
# **Train test split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)
print(X_train.shape),
print(X_test.shape),
print(y_train.shape),
print(y_test.shape)
# Out:
# (2724, 10)
# (682, 10)
# (2724,)
# (682,)

# %% [markdown]
# $Step-5$
#
# **Read the base model**

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeClassifier
grid_tree=DecisionTreeClassifier()   # Base model
grid_tree
# Out:
# DecisionTreeClassifier()

# %%
grid_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# You need to create dictonary with hyper parameters
param_grid = {
    "criterion":['gini','entropy'], # 2
    'max_depth': [3, 4, 5, 6, 7, 8], # 6
    'min_samples_split': [2, 3, 4],  # 3
    'min_samples_leaf': [1, 2, 3, 4], # 4
    'random_state': [0, 42] # 2
}

# %% [markdown]
# **max_depth**:
#
#     - The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less        than  min_samples_split samples.
#
# **min_samples_split**:
#
#       - The minimum number of samples required to split an internal node:
#
# **min_samples_leaf**:
#
#        - The minimum number of samples required to be at a leaf node.

# %% [markdown]
# $Step-7$
#
# **Apply Grid Search CV**

# %%
# now these parameters to apply in a DT model

grid_search = GridSearchCV(grid_tree,  # Base model
                           param_grid, # params 
                           scoring='accuracy', # metric
                           cv=5,
                           verbose=True)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'random_state': [0, 42]},
#              scoring='accuracy', verbose=True)

# %% [markdown]
# $Step-8$
#
# **Fit the data**

# %%
import time
start=time.time()
grid_search.fit(X_train,y_train)
end=time.time()
print("Total time taken is:",(end-start))
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# Total time taken is: 20.67959761619568

# %%
dir(grid_search)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_estimator_type',
#  '_format_results',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_required_parameters',
#  '_run_search',
#  '_select_best_index',
#  '_validate_data',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'feature_names_in_',
#  'fit',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %% [markdown]
# $Step-9$:
#
# **Get the best parameters**

# %%
grid_search.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'random_state': [0, 42]},
#              scoring='accuracy', verbose=True)>

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=4,
#                        random_state=0)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'random_state': 0}

# %%
grid_search.best_score_
# Out:
# 0.8649001618996222

# %%
with open('cv_results.txt','w') as file:
    file.write(str(grid_search.cv_results_))

# %%
cv_results=grid_search.cv_results_
cv_results
# Out:
# {'mean_fit_time': array([0.01015234, 0.00558219, 0.00614371, 0.00871754, 0.00984583,
#         0.00626678, 0.00698042, 0.00639391, 0.00808768, 0.00968618,
#         0.00452967, 0.00737414, 0.00604181, 0.00541258, 0.00681653,
#         0.00614271, 0.00749974, 0.0059361 , 0.00510674, 0.0053462 ,
#         0.00730395, 0.00562143, 0.00539551, 0.00530248, 0.00608191,
#         0.00788894, 0.00860953, 0.00844865, 0.01081214, 0.00864596,
#         0.00918608, 0.01150017, 0.01173701, 0.00881481, 0.00789475,
#         0.01169367, 0.00991554, 0.0076611 , 0.00795102, 0.00780826,
#         0.01136837, 0.00844026, 0.00902324, 0.00871234, 0.01232371,
#         0.01266689, 0.00698366, 0.01095443, 0.0092114 , 0.0102983 ,
#         0.00823851, 0.00935817, 0.00894885, 0.00684457, 0.00829244,
#         0.00710564, 0.00718975, 0.00862212, 0.00985932, 0.0096508 ,
#         0.00926056, 0.00951395, 0.00755725, 0.00886765, 0.01126003,
#         0.01267314, 0.01300244, 0.01442122, 0.0142971 , 0.01617789,
#         0.01083612, 0.00735822, 0.00936546, 0.00951548, 0.01173887,
#         0.01094165, 0.01322923, 0.01509504, 0.01243482, 0.01003385,
#         0.00914226, 0.01036558, 0.00921245, 0.00802422, 0.00966306,
#         0.00806503, 0.00967298, 0.01094499, 0.01429667, 0.01145186,
#         0.00938444, 0.01062155, 0.00825291, 0.0119328 , 0.0129518 ,
#         0.01812305, 0.01253262, 0.01447964, 0.01669879, 0.01758871,
#         0.01521106, 0.00959177, 0.01061325, 0.01243744, 0.01557899,
#         0.01282263, 0.01154213, 0.01323028, 0.01234231, 0.01033564,
#         0.01295729, 0.01183839, 0.00890584, 0.00887837, 0.01072817,
#         0.01064854, 0.00942688, 0.00990376, 0.00893211, 0.01015282,
#         0.00979471, 0.00942788, 0.01221242, 0.01552663, 0.01362233,
#         0.01970749, 0.01676984, 0.01846642, 0.01576986, 0.01145978,
#         0.01367774, 0.01112247, 0.00903406, 0.01480327, 0.01693649,
#         0.0124001 , 0.01127563, 0.01383185, 0.01051574, 0.01504059,
#         0.0118896 , 0.01188145, 0.01002855, 0.01259003, 0.010181  ,
#         0.01229577, 0.00662503, 0.00571103, 0.00777369, 0.00895338,
#         0.007899  , 0.01396937, 0.00742807, 0.01098146, 0.01131415,
#         0.01056437, 0.00904827, 0.01055121, 0.00673399, 0.00879984,
#         118, 112, 118, 112, 118, 112,  31,  36,  31,  36,  36,  57,  69,
#          64,  69,  64,  69,  64,  45,  61,  45,  61,  45,  61,  28,  33,
#          28,  33,  28,  33,   4,   7,   4,   8,   6,   8,  16,  19,  16,
#          19,  16,  19,  22,  13,  22,  13,  22,  13,   1,  10,   1,  10,
#           1,  10])}

# %%
cv_results.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_criterion', 'param_max_depth', 'param_min_samples_leaf', 'param_min_samples_split', 'param_random_state', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
len(cv_results['split0_test_score'])
# Out:
# 288

# %%
df=pd.DataFrame()
df['split0']=cv_results['split0_test_score']
df['split1']=cv_results['split1_test_score']
df['split2']=cv_results['split2_test_score']
df['split3']=cv_results['split3_test_score']
df['split4']=cv_results['split4_test_score']
#df['mean_test_score']=cv_results['mean_test_score']
df
# Out:
#        split0    split1    split2    split3    split4
# 0    0.827523  0.829358  0.814679  0.825688  0.810662
# 1    0.827523  0.829358  0.814679  0.825688  0.810662
# 2    0.827523  0.829358  0.814679  0.825688  0.810662
# 3    0.827523  0.829358  0.814679  0.825688  0.810662
# 4    0.827523  0.829358  0.814679  0.825688  0.810662
# ..        ...       ...       ...       ...       ...
# 283  0.877064  0.871560  0.851376  0.858716  0.845588
# 284  0.880734  0.880734  0.849541  0.860550  0.852941
# 285  0.877064  0.871560  0.851376  0.858716  0.845588
# 286  0.880734  0.880734  0.849541  0.860550  0.852941
# 287  0.877064  0.871560  0.851376  0.858716  0.845588
#
# [288 rows x 5 columns]

# %%
mean_score=[i.mean() for i in df.values]
df['mean_score']=mean_score
df['mean_test_score']=cv_results['mean_test_score']
df
# Out:
#        split0    split1    split2    split3    split4  mean_score  \
# 0    0.827523  0.829358  0.814679  0.825688  0.810662    0.821582
# 1    0.827523  0.829358  0.814679  0.825688  0.810662    0.821582
# 2    0.827523  0.829358  0.814679  0.825688  0.810662    0.821582
# 3    0.827523  0.829358  0.814679  0.825688  0.810662    0.821582
# 4    0.827523  0.829358  0.814679  0.825688  0.810662    0.821582
# ..        ...       ...       ...       ...       ...         ...
# 283  0.877064  0.871560  0.851376  0.858716  0.845588    0.860861
# 284  0.880734  0.880734  0.849541  0.860550  0.852941    0.864900
# 285  0.877064  0.871560  0.851376  0.858716  0.845588    0.860861
# 286  0.880734  0.880734  0.849541  0.860550  0.852941    0.864900
# 287  0.877064  0.871560  0.851376  0.858716  0.845588    0.860861
#
#      mean_test_score
# 0           0.821582
# 1           0.821582
# 2           0.821582
# 3           0.821582
# 4           0.821582
# ..               ...
# 283         0.860861
# 284         0.864900
# 285         0.860861
# 286         0.864900
# 287         0.860861
#
# [288 rows x 7 columns]

# %%
max(mean_score)
# Out:
# 0.8649001618996222

# %%
grid_search.best_score_
# Out:
# 0.8649001618996222

# %%
grid_search.best_params_
# The below paramters is one combination out of 288 combinations
# This combination applied how many times
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'random_state': 0}

# %% [markdown]
# **Cross validation score**
#
# - Imagine that we get our best model
#
# - which means out of 1440 fits , we got the best parameter
#
# - So that best parameter applied for all 5 splittes
#
# - It will give 5 accuracy values
#
# - The average of 5 accuracy values become our best score

# %%
best_model_dt=grid_search.best_estimator_
cv_acc_list=cross_val_score(best_model_dt,
                X_train,
               y_train,
               cv=5,
               scoring='accuracy')
cv_acc_list
# Out:
# array([0.88073394, 0.88073394, 0.84954128, 0.86055046, 0.85294118])

# %%
print('The best parameter of accuracy of the split0 is:',cv_acc_list[0])
print('The best parameter of accuracy of the split1 is:',cv_acc_list[1])
print('The best parameter of accuracy of the split2 is:',cv_acc_list[2])
print('The best parameter of accuracy of the split3 is:',cv_acc_list[3])
print('The best parameter of accuracy of the split4 is:',cv_acc_list[4])
# Out:
# The best parameter of accuracy of the split0 is: 0.8807339449541285
# The best parameter of accuracy of the split1 is: 0.8807339449541285
# The best parameter of accuracy of the split2 is: 0.8495412844036697
# The best parameter of accuracy of the split3 is: 0.8605504587155963
# The best parameter of accuracy of the split4 is: 0.8529411764705882

# %%
cv_acc_list.mean()
# Out:
# 0.8649001618996222

# %%
grid_search.best_score_
# Out:
# 0.8649001618996222

# %% [markdown]
# - Perform the Best model on train data
#
# - Apply the X_test get the predictions
#
# - Calculate accuracy, precision,recall,f1score etc.
#
# - Compare the without parameter tuning with parameter tuning

# %% [markdown]
# **Base model: with out hyper parameter tuning**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train, y_train)

# =============================Step-5:  Predictions============================================================

y_pred_dt=dtree.predict(X_test)

# ============================ Step-6: Metrics==================================================================

acc_dt= round(accuracy_score(y_test,y_pred_dt)*100,2)
f1_dt=round(f1_score(y_test,y_pred_dt),2)
precision_dt=round(precision_score(y_test,y_pred_dt),2)
recall_dt=round(recall_score(y_test,y_pred_dt),2)

print("accuray is:",acc_dt)
print("F1 is:",f1_dt)
print("Precision is:",precision_dt)
print("Recall is:",recall_dt)
#print(classification_report(y_test,y_pred_dt))

# ================================Step-7:Confusion matrix=========================================================================

cmt=confusion_matrix(y_test,y_pred_dt)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_dt).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)

#=======================================Step-8: ROC-AUC curve================================================================

y_dt_pred_prob=dtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_dt_pred_prob) 
plt.plot([0,1],[0,1],color="navy",lw=2,label="Random-Model")
plt.plot(fpr,tpr,color="darkorange",label="Decision Tree")
plt.legend()
plt.show()
# Out:
# accuray is: 89.59
# F1 is: 0.9
# Precision is: 0.9
# Recall is: 0.9
# True negative: 300
# False postive: 35
# False negative: 36
# True postive: 311

# %% [markdown]
# **Best model: with hyper parameter tuning**

# %%
best_model_dt=grid_search.best_estimator_
# =============================Step-5:  Predictions============================================================

y_pred_dt_best=best_model_dt.predict(X_test)

# ============================ Step-6: Metrics==================================================================

acc_dt_best= round(accuracy_score(y_test,y_pred_dt_best)*100,2)
f1_dt_best=round(f1_score(y_test,y_pred_dt_best),2)
precision_dt_best=round(precision_score(y_test,y_pred_dt_best),2)
recall_dt_best=round(recall_score(y_test,y_pred_dt_best),2)

print("accuray is:",acc_dt_best)
print("F1 is:",f1_dt_best)
print("Precision is:",precision_dt_best)
print("Recall is:",recall_dt_best)
#print(classification_report(y_test,y_pred_dt))

# ================================Step-7:Confusion matrix=========================================================================

cmt_best=confusion_matrix(y_test,y_pred_dt_best)

disp_best=ConfusionMatrixDisplay(confusion_matrix=cmt_best,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_dt_best).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)

#=======================================Step-8: ROC-AUC curve================================================================

y_dt_pred_prob_best=dtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_dt_pred_prob_best) 
plt.plot([0,1],[0,1],color="navy",lw=2,label="Random-Model")
plt.plot(fpr,tpr,color="darkorange",label="Decision Tree")
plt.legend()
plt.show()
# Out:
# accuray is: 88.71
# F1 is: 0.88
# Precision is: 0.92
# Recall is: 0.85
# True negative: 310
# False postive: 25
# False negative: 52
# True postive: 295

# %%
acc_dt,acc_dt_best
# Out:
# (89.59, 88.71)

# %%
precision_dt,precision_dt_best
# Out:
# (0.9, 0.92)

# %%
recall_dt,recall_dt_best
# Out:
# (0.9, 0.85)

# %%
f1_dt,f1_dt_best
# Out:
# (0.9, 0.88)

# %%
base_model_metrics=[acc_dt,precision_dt,recall_dt,f1_dt]
best_model_metrics=[acc_dt_best,precision_dt_best,recall_dt_best,f1_dt_best]
index=['Acc','Precision','Recall','F1']
cols=['Base_model_metrics','Best_model_metrics']
pd.DataFrame(zip(base_model_metrics,best_model_metrics),
            index=index,
             columns=cols)
# Out:
#            Base_model_metrics  Best_model_metrics
# Acc                     89.59               88.71
# Precision                0.90                0.92
# Recall                   0.90                0.85
# F1                       0.90                0.88

# %% [markdown]
# **Important features**

# %%
dtree.feature_importances_
# Out:
# array([0.01044971, 0.07872338, 0.06379343, 0.0931566 , 0.04672374,
#        0.25489268, 0.0717151 , 0.04264113, 0.13916961, 0.19873461])

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": dtree.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)
fi
# Out:
#              Feature Name  Importance
# 5     weekly_mins_watched    0.254893
# 9  customer_support_calls    0.198735
# 8          videos_watched    0.139170
# 3            multi_screen    0.093157
# 1                     age    0.078723
# 6      minimum_daily_mins    0.071715
# 2   no_of_days_subscribed    0.063793
# 4         mail_subscribed    0.046724
# 7   weekly_max_night_mins    0.042641
# 0                  gender    0.010450

# %%
dtree
# Out:
# DecisionTreeClassifier()
